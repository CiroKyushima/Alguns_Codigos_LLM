# %% [markdown]
# um codigo simples para utilizar um modelo de LLM de mascarar palavras(estilo de telcldos)

# %%
from transformers import pipeline
from transformers import logging

logging.set_verbosity_error()

# %%
mascarar = pipeline("fill-mask", model="neuralmind/bert-base-portuguese-cased")
texto = mascarar("existe uma chance do corpo cair no [MASK]")
for x in range(len(texto)):
    print(texto[x])
# Out:
# Loading weights:   0%|          | 0/203 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# {'score': 0.44742071628570557, 'token': 8105, 'token_str': 'chão', 'sequence': 'existe uma chance do corpo cair no chão'}
# {'score': 0.08555411547422409, 'token': 528, 'token_str': 'mar', 'sequence': 'existe uma chance do corpo cair no mar'}
# {'score': 0.04083452373743057, 'token': 2187, 'token_str': 'rio', 'sequence': 'existe uma chance do corpo cair no rio'}
# {'score': 0.030590003356337547, 'token': 15213, 'token_str': 'buraco', 'sequence': 'existe uma chance do corpo cair no buraco'}
# {'score': 0.019790608435869217, 'token': 8096, 'token_str': 'gelo', 'sequence': 'existe uma chance do corpo cair no gelo'}
